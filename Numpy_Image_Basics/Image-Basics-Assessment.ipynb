# %% [markdown]
# <a href="https://www.pieriandata.com"><img src="../DATA/Logo.jpg"></a>

# %% [markdown]
# # Image Basics Assessment
#
# ## Complete the Tasks in bold below. Keep in mind, you may need to run some of these tasks as Python scripts.

# %% [markdown]
# ----------
# #### TASK: Open the *dog_backpack.jpg* image from the DATA folder and display it in the notebook. Make sure to correct for the RGB order.

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
import os

# %matplotlib inline

# %%
print(os.getcwd())
# Out:
# C:\Users\TYW\Desktop\CV-object-detection\Practice\Numpy_Image_Basics

# %%
image_1 = cv2.imread(r"..\DATA\dog_backpack.jpg")

# %%
plt.imshow(image_1)

# %% [markdown]
# #### TASK: Flip the image upside down and display it in the notebook.

# %%
image_1 = cv2.cvtColor(image_1,cv2.COLOR_BGR2RGB)
plt.imshow(image_1)

# %%
image_1_flipped = cv2.flip(image_1,0)
plt.imshow(image_1_flipped)

# %% [markdown]
# #### TASK: Draw an empty RED rectangle around the dogs face and display the image in the notebook.

# %%
cv2.rectangle(image_1,pt1=(225,350),pt2=(600,720),color=(255,0,0),thickness = 5)
# Out:
# array([[[250, 248, 249],
#         [250, 248, 249],
#         [250, 248, 249],
#         ...,
#         [250, 248, 249],
#         [250, 248, 249],
#         [250, 248, 249]],
#
#        [[250, 248, 249],
#         [250, 248, 249],
#         [250, 248, 249],
#         ...,
#         [250, 248, 249],
#         [250, 248, 249],
#         [250, 248, 249]],
#
#        [[250, 248, 249],
#         [250, 248, 249],
#         [250, 248, 249],
#         ...,
#         [250, 248, 249],
#         [250, 248, 249],
#         [250, 248, 249]],
#
#        ...,
#
#        [[ 50,  40,  39],
#         [ 51,  39,  39],
#         [ 52,  38,  38],
#         ...,
#         [ 73,  80,  86],
#         [ 72,  77,  81],
#         [ 70,  75,  79]],
#
#        [[ 51,  41,  40],
#         [ 52,  40,  40],
#         [ 52,  38,  38],
#         ...,
#         [ 75,  82,  88],
#         [ 73,  78,  84],
#         [ 70,  75,  79]],
#
#        [[ 52,  42,  40],
#         [ 51,  40,  38],
#         [ 53,  39,  39],
#         ...,
#         [ 78,  83,  89],
#         [ 71,  78,  84],
#         [ 67,  75,  78]]], dtype=uint8)

# %%
plt.imshow(image_1)

# %% [markdown]
# ##### TASK: Draw a BLUE TRIANGLE in the middle of the image. The size and angle is up to you, but it should be a triangle (three sides) in any orientation.

# %%
triangle_shape = np.array([[250,800] ,[650,1100],[250,1300]])

triangle_pts = triangle_shape.reshape((-1,1,2))

cv2.polylines(image_1,[triangle_pts], color = (0,0,255), isClosed=True, thickness = 5)

plt.imshow(image_1)

# %% [markdown]
# ### BONUS TASK. Can you figure our how to fill in this triangle? It requires a different function that we didn't show in the lecture! See if you can use google search to find it.
#
# [CLICK ME FOR A DIRECT LINK TO THE HINT](https://docs.opencv.org/3.0-beta/modules/imgproc/doc/drawing_functions.html#fillpoly)

# %%
triangle_2 = np.array([[500,800],[775,800],[725,1200]])

triangle_2_pts = triangle_2.reshape((-1,1,2))

cv2.fillPoly(image_1,[triangle_2_pts],color = (0,255,0))

plt.imshow(image_1)

# %% [markdown]
# #### TASK: (NOTE: YOU WILL NEED TO RUN THIS AS A SCRIPT). Create a script that opens the picture and allows you to draw empty red circles whever you click the RIGHT MOUSE BUTTON DOWN.

# %%
def draw_circle(event,x,y,flag, params):
    
    if event == cv2.EVENT_RBUTTONDOWN:
        cv2.circle(img,(x,y),radius = 50, color=(25,75,95), thickness = -1)
        
cv2.namedWindow(winname="Image")
cv2.setMouseCallback("Image",draw_circle)

img = cv2.cvtColor(image_1,cv2.COLOR_RGB2BGR)

while True:
    
    cv2.imshow("Image",img)
    
    if cv2.waitKey(20) & 0xFF == 27:
        break
        
cv2.destroyAllWindows()
